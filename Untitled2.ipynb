# %%
import vpk

# %%
# Python program to explain os.path.exists() method 
    
# importing os module 
import os
  
# Specify path
path = '/media/max/D2AE9E57AE9E33C7/Program Files (x86)/Steam/steamapps/common/dota 2 beta/game/dota/'
  
# Check whether the specified
# path exists or not
isExist = os.path.exists(path)
print(isExist)


file_path = os.path.join(path, 'pak01_dir.vpk')
isFile = os.path.isfile(file_path)
print(isFile)
# Out:
# True
# True

# %%
vpk_files = vpk.open(file_path)

# %%
len(vpk_file)
# Out:
# 50

# %%
for vpk_file in vpk_files:
    if "png" in vpk_file and "spray" in vpk_file and "teamfancontent" in vpk_file:
        print(f"{vpk_file}")
# Out:
# panorama/images/teamfancontent/season_2/111474/spray1_png.vtex_c
# panorama/images/teamfancontent/season_2/111474/spray2_png.vtex_c
# panorama/images/teamfancontent/season_2/111474/spray5_png.vtex_c
# panorama/images/teamfancontent/season_2/15/spray0_png.vtex_c
# panorama/images/teamfancontent/season_2/15/spray3_png.vtex_c
# panorama/images/teamfancontent/season_2/15/spray5_png.vtex_c
# panorama/images/teamfancontent/season_2/1520578/spray0_png.vtex_c
# panorama/images/teamfancontent/season_2/1520578/spray1_png.vtex_c
# panorama/images/teamfancontent/season_2/1520578/spray2_png.vtex_c
# panorama/images/teamfancontent/season_2/1838315/spray0_png.vtex_c
# panorama/images/teamfancontent/season_2/1838315/spray1_png.vtex_c
# panorama/images/teamfancontent/season_2/1838315/spray2_png.vtex_c
# panorama/images/teamfancontent/season_2/1883502/spray1_png.vtex_c
# panorama/images/teamfancontent/season_2/1883502/spray2_png.vtex_c
# ...

# %%
test_file = vpk_files.get_file("scripts/chat_wheels/teamfandom_chat_wheel_7_2163.txt")

# %%
print(test_file.read().decode())
# Out:
# "chat_wheel"
# {
# 	"categories"
# 	{
# 		"team_7_2163_chatwheel"
# 		{
# 			"name"		"#DOTA_TeamFanContent_TeamChatWheel"
# 			"description"		"#DOTA_TeamFanContent_TeamChatWheel"
# 			"style"		"FandomEventCategory"
# 			"fandom_team"		"2163"
# 			"messages"
# 			{
# 				"team_7_2163_spray_spray0"		"1"
# 				"team_7_2163_spray_spray1"		"1"
# 				"team_7_2163_spray_spray2"		"1"
# 				"team_7_2163_spray_spray3"		"1"
# 				"team_7_2163_voiceline_voice0"		"1"
# 				"team_7_2163_voiceline_voice1"		"1"
# 				"team_7_2163_voiceline_voice2"		"1"
# 				"team_7_2163_voiceline_voice4"		"1"
# 			}
# 		}
# 	}
# 	"messages"
# 	{
# 		"team_7_2163_spray_spray0"
# 		{
# 			"message_id"		"141497"
# 			"image"		"teamfancontent/season_7/2163/spray0.png"
# 			"texture"		"materials/particle/sprays/teamfancontent/season_7/2163/spray0.vtex"
# 			"unlock_event_id"		"EVENT_ID_TEAM_2023_TOUR1"
# 			"unlock_event_action"		"team_7_2163_grants_lv2"
# 		}
# 		"team_7_2163_spray_spray1"
# 		{
# ...

# %%
#test_file.save("raw_chatwheel.txt")

# %%
test_file
# Out:
# VPKFile('/media/max/D2AE9E57AE9E33C7/Program Files (x86)/Steam/steamapps/common/dota 2 beta/game/dota/pak01_284.vpk', filepath='scripts/chat_wheels/teamfandom_chat_wheel_8_2163.txt', preload=b'', crc32=1825590898, preload_length=0, archive_index=284, archive_offset=42067936, file_length=2595)

# %%
zai_j = vpk_files.get_file("panorama/images/teamfancontent/season_7/2163/spray0_png.vtex_c")
zai_j
# Out:
# VPKFile('/media/max/D2AE9E57AE9E33C7/Program Files (x86)/Steam/steamapps/common/dota 2 beta/game/dota/pak01_183.vpk', filepath='panorama/images/teamfancontent/season_7/2163/spray0_png.vtex_c', preload=b'', crc32=3144766770, preload_length=0, archive_index=183, archive_offset=25188112, file_length=147928)

# %%
zai_j.save("zai_j.vtex_c")
